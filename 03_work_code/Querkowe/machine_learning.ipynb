# %% [markdown]
# # Prediction By Machine Learning
#
# ### Install

# %%
# !pip install tqdm
# !pip install lightgbm
# !pip install xgboost
# !pip install vecstack

# %%
# !pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 3.7 MB/s
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.7.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0

# %% [markdown]
# ### Import

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, RobustScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

from sklearn import linear_model, svm, ensemble
from xgboost import XGBRegressor
import lightgbm

from vecstack import StackingTransformer

from collections import Counter

from tqdm import tqdm

# %%
from skopt import BayesSearchCV
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as stats
from skopt.space import Categorical, Integer

# %% [markdown]
# ### Prepare the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/Querkowe
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/Querkowe

# %%
train_data = pd.read_csv('../Data/FIFA_train.csv')

# %%
train_data.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0

# %%
train_data.shape
# Out:
# (8932, 12)

# %%
#contract_until 변수 int 형으로 변환
# 계약 연도만 추출
def func(string:object) -> int:
    """계약 연도만 추출하여 int로 반환"""
    string = string[-4:]
    return int(string)


train_data['contract_until'] = train_data['contract_until'].apply(func)

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data[train_data.keys().drop(['id', 'name', 'value'])], train_data['value'])

# %%
x_train.head()
# Out:
#       age      continent  contract_until position prefer_foot  reputation  \
# 4931   21         europe            2022       MF       right         1.0
# 7493   19           asia            2021       ST        left         1.0
# 8820   18         europe            2023       MF       right         1.0
# 8054   20  south america            2021       MF       right         1.0
# 5341   33         europe            2019       ST       right         1.0
#
#       stat_overall  stat_potential  stat_skill_moves
# 4931            66              71               3.0
# 7493            60              70               2.0
# 8820            52              70               2.0
# 8054            58              66               2.0
# 5341            66              66               2.0

# %%
x_test.shape
# Out:
# (2233, 9)

# %% [markdown]
# #### Pipeline Preprocess

# %%
numeric_features = ['age', 'reputation', 'stat_overall', 'stat_potential', 'stat_skill_moves']
numeric_transformer = StandardScaler() # RobustScaler

categorical_features = ['continent', 'position', 'prefer_foot']
categorical_transformer = OneHotEncoder(categories='auto', handle_unknown='ignore') 

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
preprocessor_pipe = Pipeline(steps=[('preprocessor', preprocessor)])

preprocessor_pipe.fit(x_train)

x_train_transformed = preprocessor_pipe.transform(x_train)

# %% [markdown]
# ### Grid Search

# %%
svr_param_grid = {'C' : [0.1, 1, 10, 100, 1000], 
             'gamma' : [1, 0.1, 0.01, 0.001, 0.0001],
             'kernel' : ['rbf']}

svr_grid = GridSearchCV(svm.SVR(), svr_param_grid, refit=True, verbose=2)

svr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', svr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   3.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.7s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   3.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   6.5s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   3.2s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   3.4s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   3.1s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.7s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.7s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   3.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.7s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   3.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   3.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   3.7s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.8s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   3.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   3.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   3.2s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.5s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.9s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   3.9s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   3.9s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   3.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.8s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   3.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.9s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   3.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.9s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   3.0s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.5s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# The best parameters are  {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
lsvr_param_grid = {'C' : [0.1, 1, 10, 100, 1000]}

lsvr_grid = GridSearchCV(svm.LinearSVR(), lsvr_param_grid, refit=True, verbose=2)

lsvr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lsvr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# The best parameters are  {'C': 1000}

# %%
xtr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [3, 4, 5, 8]
}

xtr_grid = GridSearchCV(ensemble.ExtraTreesRegressor(), xtr_param_grid, refit=True, verbose=2)

xtr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xtr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   1.7s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.4s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.4s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.4s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.6s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.6s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.6s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.6s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.7s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.0s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.1s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   1.8s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   1.9s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   1.9s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   1.9s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   1.9s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   3.6s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   3.5s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.1s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.1s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.1s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.0s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.7s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.3s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.3s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.2s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.3s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.3s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.0s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   2.9s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.0s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.0s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.0s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   5.7s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   5.7s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   5.8s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   5.7s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   5.7s
# The best parameters are  {'max_depth': 8, 'n_estimators': 200, 'n_jobs': -1}

# %%
rfr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [3, 4, 5, 8]
}

rfr_grid = GridSearchCV(ensemble.RandomForestRegressor(), rfr_param_grid, refit=True, verbose=2)

rfr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', rfr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=100, n_jobs=-1; total time=   0.5s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=3, n_estimators=200, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   1.9s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   2.0s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   2.0s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   2.0s
# [CV] END ...........max_depth=3, n_estimators=500, n_jobs=-1; total time=   2.0s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.8s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.7s
# [CV] END ..........max_depth=3, n_estimators=1000, n_jobs=-1; total time=   3.6s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=4, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   1.0s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   1.0s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   1.0s
# [CV] END ...........max_depth=4, n_estimators=200, n_jobs=-1; total time=   0.9s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ...........max_depth=4, n_estimators=500, n_jobs=-1; total time=   2.2s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   4.2s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   4.1s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   4.2s
# [CV] END ..........max_depth=4, n_estimators=1000, n_jobs=-1; total time=   4.2s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=100, n_jobs=-1; total time=   0.6s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   1.1s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   1.1s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   1.1s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   1.1s
# [CV] END ...........max_depth=5, n_estimators=200, n_jobs=-1; total time=   1.0s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.5s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.5s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.5s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.5s
# [CV] END ...........max_depth=5, n_estimators=500, n_jobs=-1; total time=   2.5s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.7s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.7s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.8s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.7s
# [CV] END ..........max_depth=5, n_estimators=1000, n_jobs=-1; total time=   4.7s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=8, n_estimators=100, n_jobs=-1; total time=   0.8s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.4s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.4s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.4s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.4s
# [CV] END ...........max_depth=8, n_estimators=200, n_jobs=-1; total time=   1.4s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.4s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.3s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.4s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.4s
# [CV] END ...........max_depth=8, n_estimators=500, n_jobs=-1; total time=   3.3s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   6.5s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   6.4s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   6.4s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   6.5s
# [CV] END ..........max_depth=8, n_estimators=1000, n_jobs=-1; total time=   6.5s
# The best parameters are  {'max_depth': 8, 'n_estimators': 200, 'n_jobs': -1}

# %%
gbr_param_grid = {
    'n_estimators' : [100, 200, 500]
    , 'max_depth' : [3, 4, 5]
    , 'learning_rate' : [0.001, 0.01, 0.05, 0.1]
}

gbr_grid = GridSearchCV(ensemble.GradientBoostingRegressor(), gbr_param_grid, refit=True, verbose=2)

gbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', gbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END .learning_rate=0.001, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=100; total time=   0.6s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END .learning_rate=0.001, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=500; total time=   3.3s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=500; total time=   3.9s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END .learning_rate=0.001, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   3.5s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   3.5s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   4.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   3.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=200; total time=   1.0s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=200; total time=   1.0s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=500; total time=   3.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=500; total time=   3.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=200; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=200; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=200; total time=   1.0s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=200; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=200; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   3.2s
# The best parameters are  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}

# %%
xgbr_param_grid = {
    'n_estimators' : [200, 500, 1000]
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [3, 4, 5]
    , 'learning_rate' : [0.001, 0.01, 0.05, 0.1]
}

xgbr_grid = GridSearchCV(XGBRegressor(), xgbr_param_grid, refit=True, verbose=2)

xgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xgbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [06:49:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.8s
# [06:49:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:49:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:49:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:49:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:49:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:49:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:49:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.5s
# [06:49:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:49:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:49:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:49:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:49:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:50:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:50:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:50:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:50:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:50:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:50:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:50:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:50:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:50:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:50:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:50:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:50:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:50:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.7s
# [06:50:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:50:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:50:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:50:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:50:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:50:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:50:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:50:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:50:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:50:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:50:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:50:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:50:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:50:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:50:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:50:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:51:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:51:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:51:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:51:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.6s
# [06:51:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.6s
# [06:51:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.6s
# [06:51:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.6s
# [06:51:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.6s
# [06:51:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   1.4s
# [06:51:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   1.4s
# [06:51:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   1.4s
# [06:51:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   1.4s
# [06:51:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   1.4s
# [06:51:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:51:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:51:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:51:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:51:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:51:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.7s
# [06:51:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.7s
# [06:51:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.7s
# [06:51:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.7s
# [06:51:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.7s
# [06:51:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   1.8s
# [06:51:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   1.8s
# [06:51:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   1.8s
# [06:51:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   1.8s
# [06:51:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   1.8s
# [06:51:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:51:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:51:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:52:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:52:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:52:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.9s
# [06:52:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.9s
# [06:52:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.9s
# [06:52:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.9s
# [06:52:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.9s
# [06:52:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   2.2s
# [06:52:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   2.2s
# [06:52:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   2.2s
# [06:52:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   2.3s
# [06:52:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   2.2s
# [06:52:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   4.3s
# [06:52:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   4.3s
# [06:52:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   4.3s
# [06:52:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:52:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   4.3s
# [06:52:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.6s
# [06:52:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.6s
# [06:52:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.6s
# [06:52:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.6s
# [06:52:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200; total time=   0.6s
# [06:52:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   1.4s
# [06:52:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   1.4s
# [06:52:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   1.4s
# [06:52:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   1.4s
# [06:52:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   1.4s
# [06:52:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:52:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:53:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:53:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:53:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:53:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [06:53:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [06:53:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [06:53:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [06:53:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [06:53:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [06:53:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [06:53:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [06:53:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [06:53:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [06:53:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:53:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:53:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:53:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.7s
# [06:53:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:53:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [06:53:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   1.1s
# [06:53:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [06:53:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [06:53:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [06:53:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [06:53:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [06:53:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.4s
# [06:53:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [06:53:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [06:53:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.6s
# [06:54:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.4s
# [06:54:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   5.2s
# [06:54:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:54:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:54:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [06:54:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [06:54:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [06:54:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [06:54:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [06:54:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.8s
# [06:54:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.5s
# [06:54:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [06:54:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [06:54:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [06:54:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:54:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:54:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:54:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:54:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:54:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [06:54:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [06:54:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [06:54:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [06:54:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [06:54:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [06:54:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [06:54:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [06:54:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [06:54:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [06:54:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:55:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:55:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:55:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.7s
# [06:55:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.7s
# [06:55:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [06:55:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [06:55:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [06:55:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [06:55:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [06:55:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [06:55:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.2s
# [06:55:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [06:55:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.2s
# [06:55:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [06:55:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:55:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:55:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:55:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:55:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [06:55:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:55:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:55:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:55:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:55:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; total time=   0.6s
# [06:55:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:55:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:56:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.5s
# [06:56:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:56:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; total time=   1.4s
# [06:56:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:56:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:56:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:56:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.9s
# [06:56:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; total time=   2.8s
# [06:56:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:56:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:56:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:56:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:56:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=200; total time=   0.7s
# [06:56:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:56:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:56:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:56:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:56:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=500; total time=   1.8s
# [06:56:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.5s
# [06:56:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:56:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:56:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:56:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=4, n_estimators=1000; total time=   3.6s
# [06:56:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:56:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:56:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:56:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:56:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=200; total time=   0.9s
# [06:56:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:56:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:56:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:57:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# [06:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=500; total time=   2.2s
# ...
# [07:05:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [07:05:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=200; total time=   0.7s
# [07:05:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [07:05:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [07:05:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [07:05:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [07:05:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=500; total time=   1.8s
# [07:05:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:05:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:05:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:06:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:06:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:06:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [07:06:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [07:06:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [07:06:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [07:06:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=200; total time=   0.9s
# [07:06:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.3s
# [07:06:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [07:06:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [07:06:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [07:06:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=500; total time=   2.2s
# [07:06:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:06:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:06:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.4s
# [07:06:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:06:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:06:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [07:06:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [07:06:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [07:06:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [07:06:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.6s
# [07:06:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.5s
# [07:06:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [07:06:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [07:06:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.5s
# [07:06:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   1.4s
# [07:06:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.9s
# [07:06:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.9s
# [07:07:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [07:07:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.9s
# [07:07:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   2.8s
# [07:07:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [07:07:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.8s
# [07:07:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [07:07:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.7s
# [07:07:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.8s
# [07:07:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [07:07:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [07:07:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [07:07:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [07:07:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   1.8s
# [07:07:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:07:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:07:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:07:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:07:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.6s
# [07:07:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [07:07:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [07:07:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [07:07:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [07:07:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.9s
# [07:07:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [07:07:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [07:07:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [07:07:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [07:07:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   2.3s
# [07:07:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:08:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:08:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:08:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.6s
# [07:08:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   4.5s
# [07:08:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# The best parameters are  {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 1000}

# %%
lgbr_param_grid = {
    'n_estimators' : [200, 500, 1000]
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [3, 4, 5]
    , 'learning_rate' : [0.001, 0.01, 0.05, 0.1]
}

lgbr_grid = GridSearchCV(lightgbm.LGBMRegressor(), lgbr_param_grid, refit=True, verbose=2)

lgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lgbr_grid.best_params_)
