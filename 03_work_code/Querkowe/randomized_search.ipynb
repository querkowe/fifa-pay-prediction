# %% [markdown]
# ### Install

# %%
# !pip install tqdm
# !pip install lightgbm
# !pip install xgboost
# !pip install vecstack
# !pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.7.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vecstack in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)

# %% [markdown]
# ### Import

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, RobustScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error

from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, LogN, Real
import scipy.stats as stats
from sklearn.utils.fixes import loguniform

from sklearn import linear_model, svm, ensemble
from xgboost import XGBRegressor
import lightgbm

from vecstack import StackingTransformer

from collections import Counter

from tqdm import tqdm

# %% [markdown]
# ### Prepare the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/03_work_code/Querkowe
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/03_work_code/Querkowe

# %%
train_data = pd.read_csv('../../00_original_data/FIFA_train.csv')

# %%
#contract_until 변수 int 형으로 변환
# 계약 연도만 추출
def func(string:object) -> int:
    """계약 연도만 추출하여 int로 반환"""
    string = string[-4:]
    return int(string)


train_data['contract_until'] = train_data['contract_until'].apply(func)

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data[train_data.keys().drop(['id', 'name', 'value'])], train_data['value'], random_state=42)

# %% [markdown]
# #### Pipeline Preprocess

# %%
numeric_features = ['age', 'reputation', 'stat_overall', 'stat_potential', 'stat_skill_moves']
numeric_transformer = StandardScaler() # RobustScaler

categorical_features = ['continent', 'position', 'prefer_foot']
categorical_transformer = OneHotEncoder(categories='auto', handle_unknown='ignore') 

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
preprocessor_pipe = Pipeline(steps=[('preprocessor', preprocessor)])

preprocessor_pipe.fit(x_train)

x_train_transformed = preprocessor_pipe.transform(x_train)

# %% [markdown]
# ### Random Search

# %%
svr_param_grid = {'C' : loguniform(1e-1, 1e3), 
             'gamma' : loguniform(1e-4, 1e0),
             'kernel' : ['rbf']}

svr_grid = RandomizedSearchCV(svm.SVR(), svr_param_grid, refit=True, verbose=2)

svr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', svr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END C=1.0683930644884565, gamma=0.0009364150677682173, kernel=rbf; total time=   3.2s
# [CV] END C=1.0683930644884565, gamma=0.0009364150677682173, kernel=rbf; total time=   3.3s
# [CV] END C=1.0683930644884565, gamma=0.0009364150677682173, kernel=rbf; total time=   5.5s
# [CV] END C=1.0683930644884565, gamma=0.0009364150677682173, kernel=rbf; total time=   5.6s
# [CV] END C=1.0683930644884565, gamma=0.0009364150677682173, kernel=rbf; total time=   6.1s
# [CV] END C=16.803646390985232, gamma=0.0811957710059441, kernel=rbf; total time=   3.7s
# [CV] END C=16.803646390985232, gamma=0.0811957710059441, kernel=rbf; total time=   2.8s
# [CV] END C=16.803646390985232, gamma=0.0811957710059441, kernel=rbf; total time=   3.3s
# [CV] END C=16.803646390985232, gamma=0.0811957710059441, kernel=rbf; total time=   3.5s
# [CV] END C=16.803646390985232, gamma=0.0811957710059441, kernel=rbf; total time=   2.7s
# [CV] END C=0.31140694890520054, gamma=0.0019355254326236214, kernel=rbf; total time=   2.6s
# [CV] END C=0.31140694890520054, gamma=0.0019355254326236214, kernel=rbf; total time=   2.7s
# [CV] END C=0.31140694890520054, gamma=0.0019355254326236214, kernel=rbf; total time=   2.6s
# [CV] END C=0.31140694890520054, gamma=0.0019355254326236214, kernel=rbf; total time=   2.7s
# [CV] END C=0.31140694890520054, gamma=0.0019355254326236214, kernel=rbf; total time=   2.6s
# [CV] END C=417.8148444007955, gamma=0.3547275579413753, kernel=rbf; total time=   2.6s
# [CV] END C=417.8148444007955, gamma=0.3547275579413753, kernel=rbf; total time=   2.6s
# [CV] END C=417.8148444007955, gamma=0.3547275579413753, kernel=rbf; total time=   2.6s
# [CV] END C=417.8148444007955, gamma=0.3547275579413753, kernel=rbf; total time=   2.6s
# [CV] END C=417.8148444007955, gamma=0.3547275579413753, kernel=rbf; total time=   2.6s
# [CV] END C=0.32606368925621476, gamma=0.0007076442275588424, kernel=rbf; total time=   2.6s
# [CV] END C=0.32606368925621476, gamma=0.0007076442275588424, kernel=rbf; total time=   2.7s
# [CV] END C=0.32606368925621476, gamma=0.0007076442275588424, kernel=rbf; total time=   2.6s
# [CV] END C=0.32606368925621476, gamma=0.0007076442275588424, kernel=rbf; total time=   2.6s
# [CV] END C=0.32606368925621476, gamma=0.0007076442275588424, kernel=rbf; total time=   2.6s
# [CV] END C=1.8051640870507908, gamma=0.024503752886942887, kernel=rbf; total time=   2.6s
# [CV] END C=1.8051640870507908, gamma=0.024503752886942887, kernel=rbf; total time=   2.6s
# [CV] END C=1.8051640870507908, gamma=0.024503752886942887, kernel=rbf; total time=   2.7s
# [CV] END C=1.8051640870507908, gamma=0.024503752886942887, kernel=rbf; total time=   2.6s
# [CV] END C=1.8051640870507908, gamma=0.024503752886942887, kernel=rbf; total time=   2.6s
# [CV] END C=0.3871104585038383, gamma=0.03788026672085542, kernel=rbf; total time=   2.6s
# [CV] END C=0.3871104585038383, gamma=0.03788026672085542, kernel=rbf; total time=   2.7s
# [CV] END C=0.3871104585038383, gamma=0.03788026672085542, kernel=rbf; total time=   2.6s
# [CV] END C=0.3871104585038383, gamma=0.03788026672085542, kernel=rbf; total time=   2.6s
# [CV] END C=0.3871104585038383, gamma=0.03788026672085542, kernel=rbf; total time=   2.6s
# [CV] END C=311.4670902497984, gamma=0.000381357771394047, kernel=rbf; total time=   2.6s
# [CV] END C=311.4670902497984, gamma=0.000381357771394047, kernel=rbf; total time=   2.6s
# [CV] END C=311.4670902497984, gamma=0.000381357771394047, kernel=rbf; total time=   2.6s
# [CV] END C=311.4670902497984, gamma=0.000381357771394047, kernel=rbf; total time=   3.1s
# [CV] END C=311.4670902497984, gamma=0.000381357771394047, kernel=rbf; total time=   2.6s
# [CV] END C=1.4742090183841576, gamma=0.028123950388165998, kernel=rbf; total time=   2.6s
# [CV] END C=1.4742090183841576, gamma=0.028123950388165998, kernel=rbf; total time=   2.6s
# [CV] END C=1.4742090183841576, gamma=0.028123950388165998, kernel=rbf; total time=   2.6s
# [CV] END C=1.4742090183841576, gamma=0.028123950388165998, kernel=rbf; total time=   2.6s
# [CV] END C=1.4742090183841576, gamma=0.028123950388165998, kernel=rbf; total time=   2.6s
# [CV] END C=2.1005562844950574, gamma=0.005229721716680315, kernel=rbf; total time=   2.6s
# [CV] END C=2.1005562844950574, gamma=0.005229721716680315, kernel=rbf; total time=   2.6s
# [CV] END C=2.1005562844950574, gamma=0.005229721716680315, kernel=rbf; total time=   2.6s
# [CV] END C=2.1005562844950574, gamma=0.005229721716680315, kernel=rbf; total time=   3.6s
# [CV] END C=2.1005562844950574, gamma=0.005229721716680315, kernel=rbf; total time=   2.6s
# The best parameters are  {'C': 417.8148444007955, 'gamma': 0.3547275579413753, 'kernel': 'rbf'}

# %%
lsvr_param_grid = {'C' : loguniform(1e-1, 1e3)
                   , 'random_state' : [42]}

lsvr_grid = RandomizedSearchCV(svm.LinearSVR(), lsvr_param_grid, refit=True, verbose=2)

lsvr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lsvr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .............C=0.11098748365891312, random_state=42; total time=   0.0s
# [CV] END .............C=0.11098748365891312, random_state=42; total time=   0.0s
# [CV] END .............C=0.11098748365891312, random_state=42; total time=   0.0s
# [CV] END .............C=0.11098748365891312, random_state=42; total time=   0.0s
# [CV] END .............C=0.11098748365891312, random_state=42; total time=   0.0s
# [CV] END ..............C=16.371258949096802, random_state=42; total time=   0.0s
# [CV] END ..............C=16.371258949096802, random_state=42; total time=   0.0s
# [CV] END ..............C=16.371258949096802, random_state=42; total time=   0.0s
# [CV] END ..............C=16.371258949096802, random_state=42; total time=   0.0s
# [CV] END ..............C=16.371258949096802, random_state=42; total time=   0.0s
# [CV] END .............C=0.11171714662708848, random_state=42; total time=   0.0s
# [CV] END .............C=0.11171714662708848, random_state=42; total time=   0.0s
# [CV] END .............C=0.11171714662708848, random_state=42; total time=   0.0s
# [CV] END .............C=0.11171714662708848, random_state=42; total time=   0.0s
# [CV] END .............C=0.11171714662708848, random_state=42; total time=   0.0s
# [CV] END ..............C=0.3098651669826842, random_state=42; total time=   0.0s
# [CV] END ..............C=0.3098651669826842, random_state=42; total time=   0.0s
# [CV] END ..............C=0.3098651669826842, random_state=42; total time=   0.0s
# [CV] END ..............C=0.3098651669826842, random_state=42; total time=   0.0s
# [CV] END ..............C=0.3098651669826842, random_state=42; total time=   0.0s
# [CV] END ...............C=4.710409561835159, random_state=42; total time=   0.0s
# [CV] END ...............C=4.710409561835159, random_state=42; total time=   0.0s
# [CV] END ...............C=4.710409561835159, random_state=42; total time=   0.0s
# [CV] END ...............C=4.710409561835159, random_state=42; total time=   0.0s
# [CV] END ...............C=4.710409561835159, random_state=42; total time=   0.0s
# [CV] END ..............C=2.3857570387177165, random_state=42; total time=   0.0s
# [CV] END ..............C=2.3857570387177165, random_state=42; total time=   0.0s
# [CV] END ..............C=2.3857570387177165, random_state=42; total time=   0.0s
# [CV] END ..............C=2.3857570387177165, random_state=42; total time=   0.0s
# [CV] END ..............C=2.3857570387177165, random_state=42; total time=   0.0s
# [CV] END ..............C=0.5437773954429072, random_state=42; total time=   0.0s
# [CV] END ..............C=0.5437773954429072, random_state=42; total time=   0.0s
# [CV] END ..............C=0.5437773954429072, random_state=42; total time=   0.0s
# [CV] END ..............C=0.5437773954429072, random_state=42; total time=   0.0s
# [CV] END ..............C=0.5437773954429072, random_state=42; total time=   0.0s
# [CV] END ...............C=524.8859871129727, random_state=42; total time=   0.0s
# [CV] END ...............C=524.8859871129727, random_state=42; total time=   0.0s
# [CV] END ...............C=524.8859871129727, random_state=42; total time=   0.0s
# [CV] END ...............C=524.8859871129727, random_state=42; total time=   0.0s
# [CV] END ...............C=524.8859871129727, random_state=42; total time=   0.0s
# [CV] END ..............C=1.5759863536941245, random_state=42; total time=   0.0s
# [CV] END ..............C=1.5759863536941245, random_state=42; total time=   0.0s
# [CV] END ..............C=1.5759863536941245, random_state=42; total time=   0.0s
# [CV] END ..............C=1.5759863536941245, random_state=42; total time=   0.0s
# [CV] END ..............C=1.5759863536941245, random_state=42; total time=   0.0s
# [CV] END ...............C=39.40959856517731, random_state=42; total time=   0.0s
# [CV] END ...............C=39.40959856517731, random_state=42; total time=   0.0s
# [CV] END ...............C=39.40959856517731, random_state=42; total time=   0.0s
# [CV] END ...............C=39.40959856517731, random_state=42; total time=   0.0s
# [CV] END ...............C=39.40959856517731, random_state=42; total time=   0.0s
# The best parameters are  {'C': 524.8859871129727, 'random_state': 42}

# %%
xtr_param_grid = {
    'n_estimators' : stats.randint(100, 1000)
    , 'n_jobs' : [-1]
    , 'max_depth' : stats.randint(-1, 5)
    , 'random_state' : [42]
}

xtr_grid = RandomizedSearchCV(ensemble.ExtraTreesRegressor(), xtr_param_grid, refit=True, verbose=2)

xtr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xtr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=1, n_estimators=339, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=1, n_estimators=339, n_jobs=-1, random_state=42; total time=   0.8s
# [CV] END max_depth=1, n_estimators=339, n_jobs=-1, random_state=42; total time=   0.8s
# [CV] END max_depth=1, n_estimators=339, n_jobs=-1, random_state=42; total time=   0.8s
# [CV] END max_depth=1, n_estimators=339, n_jobs=-1, random_state=42; total time=   0.8s
# [CV] END max_depth=4, n_estimators=815, n_jobs=-1, random_state=42; total time=   2.9s
# [CV] END max_depth=4, n_estimators=815, n_jobs=-1, random_state=42; total time=   3.0s
# [CV] END max_depth=4, n_estimators=815, n_jobs=-1, random_state=42; total time=   3.0s
# [CV] END max_depth=4, n_estimators=815, n_jobs=-1, random_state=42; total time=   3.0s
# [CV] END max_depth=4, n_estimators=815, n_jobs=-1, random_state=42; total time=   3.0s
# [CV] END max_depth=2, n_estimators=138, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=2, n_estimators=138, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=2, n_estimators=138, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=2, n_estimators=138, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=2, n_estimators=138, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=0, n_estimators=415, n_jobs=-1, random_state=42; total time=   0.2s
# [CV] END max_depth=0, n_estimators=415, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=0, n_estimators=415, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=0, n_estimators=415, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=0, n_estimators=415, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=2, n_estimators=882, n_jobs=-1, random_state=42; total time=   5.3s
# [CV] END max_depth=2, n_estimators=882, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=2, n_estimators=882, n_jobs=-1, random_state=42; total time=   2.3s
# [CV] END max_depth=2, n_estimators=882, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=2, n_estimators=882, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=1, n_estimators=407, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=407, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=1, n_estimators=407, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=1, n_estimators=407, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=407, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=2, n_estimators=949, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=949, n_jobs=-1, random_state=42; total time=   2.4s
# [CV] END max_depth=2, n_estimators=949, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=949, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=2, n_estimators=949, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=325, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=2, n_estimators=325, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=2, n_estimators=325, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=2, n_estimators=325, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=2, n_estimators=325, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=4, n_estimators=538, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=4, n_estimators=538, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=4, n_estimators=538, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=4, n_estimators=538, n_jobs=-1, random_state=42; total time=   3.6s
# [CV] END max_depth=4, n_estimators=538, n_jobs=-1, random_state=42; total time=   2.0s
# [CV] END max_depth=4, n_estimators=450, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=4, n_estimators=450, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=4, n_estimators=450, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=4, n_estimators=450, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=4, n_estimators=450, n_jobs=-1, random_state=42; total time=   1.6s
# The best parameters are  {'max_depth': 4, 'n_estimators': 538, 'n_jobs': -1, 'random_state': 42}

# %%
rfr_param_grid = {
    'n_estimators' : stats.randint(100, 1000)
    , 'n_jobs' : [-1]
    , 'max_depth' : stats.randint(-1, 5)
    , 'random_state' : [42]
}

rfr_grid = RandomizedSearchCV(ensemble.RandomForestRegressor(), rfr_param_grid, refit=True, verbose=2)

rfr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', rfr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=2, n_estimators=779, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=779, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=779, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=779, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=779, n_jobs=-1, random_state=42; total time=   2.4s
# [CV] END max_depth=0, n_estimators=130, n_jobs=-1, random_state=42; total time=   0.1s
# [CV] END max_depth=0, n_estimators=130, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=0, n_estimators=130, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=0, n_estimators=130, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=0, n_estimators=130, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=4, n_estimators=443, n_jobs=-1, random_state=42; total time=   3.2s
# [CV] END max_depth=4, n_estimators=443, n_jobs=-1, random_state=42; total time=   2.0s
# [CV] END max_depth=4, n_estimators=443, n_jobs=-1, random_state=42; total time=   2.0s
# [CV] END max_depth=4, n_estimators=443, n_jobs=-1, random_state=42; total time=   2.0s
# [CV] END max_depth=4, n_estimators=443, n_jobs=-1, random_state=42; total time=   1.9s
# [CV] END max_depth=-1, n_estimators=889, n_jobs=-1, random_state=42; total time=   0.3s
# [CV] END max_depth=-1, n_estimators=889, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=889, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=-1, n_estimators=889, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=889, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=3, n_estimators=988, n_jobs=-1, random_state=42; total time=   4.8s
# [CV] END max_depth=3, n_estimators=988, n_jobs=-1, random_state=42; total time=   3.7s
# [CV] END max_depth=3, n_estimators=988, n_jobs=-1, random_state=42; total time=   3.7s
# [CV] END max_depth=3, n_estimators=988, n_jobs=-1, random_state=42; total time=   3.7s
# [CV] END max_depth=3, n_estimators=988, n_jobs=-1, random_state=42; total time=   3.7s
# [CV] END max_depth=3, n_estimators=106, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=106, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=3, n_estimators=106, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=3, n_estimators=106, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=3, n_estimators=106, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=3, n_estimators=650, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=3, n_estimators=650, n_jobs=-1, random_state=42; total time=   2.4s
# [CV] END max_depth=3, n_estimators=650, n_jobs=-1, random_state=42; total time=   2.4s
# [CV] END max_depth=3, n_estimators=650, n_jobs=-1, random_state=42; total time=   2.4s
# [CV] END max_depth=3, n_estimators=650, n_jobs=-1, random_state=42; total time=   2.5s
# [CV] END max_depth=2, n_estimators=225, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=2, n_estimators=225, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=2, n_estimators=225, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=2, n_estimators=225, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=2, n_estimators=225, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=1, n_estimators=359, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=359, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=359, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=359, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=1, n_estimators=359, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=-1, n_estimators=706, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=-1, n_estimators=706, n_jobs=-1, random_state=42; total time=   2.7s
# [CV] END max_depth=-1, n_estimators=706, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=706, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=706, n_jobs=-1, random_state=42; total time=   1.3s
# The best parameters are  {'max_depth': 4, 'n_estimators': 443, 'n_jobs': -1, 'random_state': 42}

# %%
gbr_param_grid = {
    'n_estimators' : stats.randint(100, 1000)
    , 'max_depth' : stats.randint(-1, 5)
    , 'learning_rate' : loguniform(1e-3, 1e-1)
    , 'random_state' : [42]
}

gbr_grid = RandomizedSearchCV(ensemble.GradientBoostingRegressor(), gbr_param_grid, refit=True, verbose=2)

gbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', gbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END learning_rate=0.06228578707760924, max_depth=2, n_estimators=663, random_state=42; total time=   1.9s
# [CV] END learning_rate=0.06228578707760924, max_depth=2, n_estimators=663, random_state=42; total time=   1.9s
# [CV] END learning_rate=0.06228578707760924, max_depth=2, n_estimators=663, random_state=42; total time=   1.9s
# [CV] END learning_rate=0.06228578707760924, max_depth=2, n_estimators=663, random_state=42; total time=   1.9s
# [CV] END learning_rate=0.06228578707760924, max_depth=2, n_estimators=663, random_state=42; total time=   1.9s
# [CV] END learning_rate=0.049577508855568365, max_depth=3, n_estimators=925, random_state=42; total time=   3.7s
# [CV] END learning_rate=0.049577508855568365, max_depth=3, n_estimators=925, random_state=42; total time=   3.8s
# [CV] END learning_rate=0.049577508855568365, max_depth=3, n_estimators=925, random_state=42; total time=   3.7s
# [CV] END learning_rate=0.049577508855568365, max_depth=3, n_estimators=925, random_state=42; total time=   3.8s
# [CV] END learning_rate=0.049577508855568365, max_depth=3, n_estimators=925, random_state=42; total time=   3.8s
# [CV] END learning_rate=0.00234335390976565, max_depth=-1, n_estimators=261, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.00234335390976565, max_depth=-1, n_estimators=261, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.00234335390976565, max_depth=-1, n_estimators=261, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.00234335390976565, max_depth=-1, n_estimators=261, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.00234335390976565, max_depth=-1, n_estimators=261, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.0023168478726495437, max_depth=4, n_estimators=850, random_state=42; total time=   4.5s
# [CV] END learning_rate=0.0023168478726495437, max_depth=4, n_estimators=850, random_state=42; total time=   4.5s
# [CV] END learning_rate=0.0023168478726495437, max_depth=4, n_estimators=850, random_state=42; total time=   4.5s
# [CV] END learning_rate=0.0023168478726495437, max_depth=4, n_estimators=850, random_state=42; total time=   4.5s
# [CV] END learning_rate=0.0023168478726495437, max_depth=4, n_estimators=850, random_state=42; total time=   4.5s
# [CV] END learning_rate=0.032441196698813485, max_depth=-1, n_estimators=640, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.032441196698813485, max_depth=-1, n_estimators=640, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.032441196698813485, max_depth=-1, n_estimators=640, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.032441196698813485, max_depth=-1, n_estimators=640, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.032441196698813485, max_depth=-1, n_estimators=640, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.005133529008968364, max_depth=0, n_estimators=560, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.005133529008968364, max_depth=0, n_estimators=560, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.005133529008968364, max_depth=0, n_estimators=560, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.005133529008968364, max_depth=0, n_estimators=560, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.005133529008968364, max_depth=0, n_estimators=560, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.02972554032353095, max_depth=4, n_estimators=534, random_state=42; total time=   2.8s
# [CV] END learning_rate=0.02972554032353095, max_depth=4, n_estimators=534, random_state=42; total time=   2.8s
# [CV] END learning_rate=0.02972554032353095, max_depth=4, n_estimators=534, random_state=42; total time=   2.8s
# [CV] END learning_rate=0.02972554032353095, max_depth=4, n_estimators=534, random_state=42; total time=   2.8s
# [CV] END learning_rate=0.02972554032353095, max_depth=4, n_estimators=534, random_state=42; total time=   2.9s
# [CV] END learning_rate=0.00965030885133629, max_depth=1, n_estimators=821, random_state=42; total time=   1.4s
# [CV] END learning_rate=0.00965030885133629, max_depth=1, n_estimators=821, random_state=42; total time=   1.4s
# [CV] END learning_rate=0.00965030885133629, max_depth=1, n_estimators=821, random_state=42; total time=   1.4s
# [CV] END learning_rate=0.00965030885133629, max_depth=1, n_estimators=821, random_state=42; total time=   1.4s
# [CV] END learning_rate=0.00965030885133629, max_depth=1, n_estimators=821, random_state=42; total time=   1.4s
# [CV] END learning_rate=0.00796053665222729, max_depth=1, n_estimators=461, random_state=42; total time=   0.8s
# [CV] END learning_rate=0.00796053665222729, max_depth=1, n_estimators=461, random_state=42; total time=   0.8s
# [CV] END learning_rate=0.00796053665222729, max_depth=1, n_estimators=461, random_state=42; total time=   0.8s
# [CV] END learning_rate=0.00796053665222729, max_depth=1, n_estimators=461, random_state=42; total time=   0.8s
# [CV] END learning_rate=0.00796053665222729, max_depth=1, n_estimators=461, random_state=42; total time=   0.8s
# [CV] END learning_rate=0.0654949254390894, max_depth=4, n_estimators=640, random_state=42; total time=   3.3s
# [CV] END learning_rate=0.0654949254390894, max_depth=4, n_estimators=640, random_state=42; total time=   3.3s
# [CV] END learning_rate=0.0654949254390894, max_depth=4, n_estimators=640, random_state=42; total time=   3.3s
# [CV] END learning_rate=0.0654949254390894, max_depth=4, n_estimators=640, random_state=42; total time=   3.3s
# [CV] END learning_rate=0.0654949254390894, max_depth=4, n_estimators=640, random_state=42; total time=   3.3s
# The best parameters are  {'learning_rate': 0.049577508855568365, 'max_depth': 3, 'n_estimators': 925, 'random_state': 42}

# %%
xgbr_param_grid = {
    'n_estimators' : stats.randint(100, 1000)
    , 'gamma' : loguniform(1e-3, 1e-1)
    , 'max_depth' : stats.randint(-1, 5)
    , 'learning_rate' : loguniform(1e-3, 1e-1)
    , 'random_state' : [42]
}

xgbr_grid = RandomizedSearchCV(XGBRegressor(), xgbr_param_grid, refit=True, verbose=2)

xgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xgbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [01:14:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.033627692968982395, learning_rate=0.0013547836593743741, max_depth=0, n_estimators=121, random_state=42; total time=   0.3s
# [01:14:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.033627692968982395, learning_rate=0.0013547836593743741, max_depth=0, n_estimators=121, random_state=42; total time=   0.1s
# [01:14:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.033627692968982395, learning_rate=0.0013547836593743741, max_depth=0, n_estimators=121, random_state=42; total time=   0.1s
# [01:14:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.033627692968982395, learning_rate=0.0013547836593743741, max_depth=0, n_estimators=121, random_state=42; total time=   0.1s
# [01:14:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.033627692968982395, learning_rate=0.0013547836593743741, max_depth=0, n_estimators=121, random_state=42; total time=   0.1s
# [01:14:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.04586484324176051, learning_rate=0.06867462147439204, max_depth=4, n_estimators=628, random_state=42; total time=   2.3s
# [01:14:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.04586484324176051, learning_rate=0.06867462147439204, max_depth=4, n_estimators=628, random_state=42; total time=   2.3s
# [01:14:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.04586484324176051, learning_rate=0.06867462147439204, max_depth=4, n_estimators=628, random_state=42; total time=   2.3s
# [01:14:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.04586484324176051, learning_rate=0.06867462147439204, max_depth=4, n_estimators=628, random_state=42; total time=   2.3s
# [01:14:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.04586484324176051, learning_rate=0.06867462147439204, max_depth=4, n_estimators=628, random_state=42; total time=   2.3s
# [01:14:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0067449783524715715, learning_rate=0.0029792604408968686, max_depth=1, n_estimators=554, random_state=42; total time=   0.9s
# [01:14:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0067449783524715715, learning_rate=0.0029792604408968686, max_depth=1, n_estimators=554, random_state=42; total time=   0.9s
# [01:14:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0067449783524715715, learning_rate=0.0029792604408968686, max_depth=1, n_estimators=554, random_state=42; total time=   0.9s
# [01:14:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0067449783524715715, learning_rate=0.0029792604408968686, max_depth=1, n_estimators=554, random_state=42; total time=   0.9s
# [01:14:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0067449783524715715, learning_rate=0.0029792604408968686, max_depth=1, n_estimators=554, random_state=42; total time=   0.9s
# [01:14:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.014398504370461163, learning_rate=0.08489607503497401, max_depth=4, n_estimators=539, random_state=42; total time=   2.0s
# [01:14:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.014398504370461163, learning_rate=0.08489607503497401, max_depth=4, n_estimators=539, random_state=42; total time=   2.0s
# [01:14:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.014398504370461163, learning_rate=0.08489607503497401, max_depth=4, n_estimators=539, random_state=42; total time=   2.0s
# [01:14:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.014398504370461163, learning_rate=0.08489607503497401, max_depth=4, n_estimators=539, random_state=42; total time=   2.0s
# [01:14:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.014398504370461163, learning_rate=0.08489607503497401, max_depth=4, n_estimators=539, random_state=42; total time=   2.0s
# [01:14:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0059807301976223465, learning_rate=0.0010372971206405466, max_depth=1, n_estimators=134, random_state=42; total time=   0.2s
# [01:14:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0059807301976223465, learning_rate=0.0010372971206405466, max_depth=1, n_estimators=134, random_state=42; total time=   0.2s
# [01:14:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0059807301976223465, learning_rate=0.0010372971206405466, max_depth=1, n_estimators=134, random_state=42; total time=   0.2s
# [01:14:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0059807301976223465, learning_rate=0.0010372971206405466, max_depth=1, n_estimators=134, random_state=42; total time=   0.2s
# [01:14:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.0059807301976223465, learning_rate=0.0010372971206405466, max_depth=1, n_estimators=134, random_state=42; total time=   0.3s
# [01:14:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.00816214846253017, learning_rate=0.00161380023500695, max_depth=1, n_estimators=575, random_state=42; total time=   1.4s
# [01:14:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.00816214846253017, learning_rate=0.00161380023500695, max_depth=1, n_estimators=575, random_state=42; total time=   1.4s
# [01:14:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.00816214846253017, learning_rate=0.00161380023500695, max_depth=1, n_estimators=575, random_state=42; total time=   1.4s
# [01:14:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.00816214846253017, learning_rate=0.00161380023500695, max_depth=1, n_estimators=575, random_state=42; total time=   0.9s
# [01:14:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.00816214846253017, learning_rate=0.00161380023500695, max_depth=1, n_estimators=575, random_state=42; total time=   0.9s
# [01:14:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001741310499715457, learning_rate=0.006767751712239987, max_depth=1, n_estimators=136, random_state=42; total time=   0.2s
# [01:14:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001741310499715457, learning_rate=0.006767751712239987, max_depth=1, n_estimators=136, random_state=42; total time=   0.2s
# [01:14:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001741310499715457, learning_rate=0.006767751712239987, max_depth=1, n_estimators=136, random_state=42; total time=   0.2s
# [01:14:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001741310499715457, learning_rate=0.006767751712239987, max_depth=1, n_estimators=136, random_state=42; total time=   0.2s
# [01:14:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001741310499715457, learning_rate=0.006767751712239987, max_depth=1, n_estimators=136, random_state=42; total time=   0.2s
# [01:14:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.09527200283335474, learning_rate=0.0025534102444595376, max_depth=1, n_estimators=826, random_state=42; total time=   1.3s
# [01:14:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.09527200283335474, learning_rate=0.0025534102444595376, max_depth=1, n_estimators=826, random_state=42; total time=   1.3s
# [01:14:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.09527200283335474, learning_rate=0.0025534102444595376, max_depth=1, n_estimators=826, random_state=42; total time=   1.3s
# [01:14:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.09527200283335474, learning_rate=0.0025534102444595376, max_depth=1, n_estimators=826, random_state=42; total time=   1.3s
# [01:14:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.09527200283335474, learning_rate=0.0025534102444595376, max_depth=1, n_estimators=826, random_state=42; total time=   1.3s
# [01:14:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.003084670916492395, learning_rate=0.030584093771360624, max_depth=1, n_estimators=469, random_state=42; total time=   0.8s
# [01:14:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.003084670916492395, learning_rate=0.030584093771360624, max_depth=1, n_estimators=469, random_state=42; total time=   0.7s
# [01:14:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.003084670916492395, learning_rate=0.030584093771360624, max_depth=1, n_estimators=469, random_state=42; total time=   0.8s
# [01:14:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.003084670916492395, learning_rate=0.030584093771360624, max_depth=1, n_estimators=469, random_state=42; total time=   0.7s
# [01:14:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.003084670916492395, learning_rate=0.030584093771360624, max_depth=1, n_estimators=469, random_state=42; total time=   0.7s
# [01:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.018596499675901816, learning_rate=0.021931853570162255, max_depth=1, n_estimators=105, random_state=42; total time=   0.2s
# [01:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.018596499675901816, learning_rate=0.021931853570162255, max_depth=1, n_estimators=105, random_state=42; total time=   0.2s
# [01:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.018596499675901816, learning_rate=0.021931853570162255, max_depth=1, n_estimators=105, random_state=42; total time=   0.2s
# [01:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.018596499675901816, learning_rate=0.021931853570162255, max_depth=1, n_estimators=105, random_state=42; total time=   0.2s
# [01:14:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.018596499675901816, learning_rate=0.021931853570162255, max_depth=1, n_estimators=105, random_state=42; total time=   0.2s
# [01:14:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# The best parameters are  {'gamma': 0.04586484324176051, 'learning_rate': 0.06867462147439204, 'max_depth': 4, 'n_estimators': 628, 'random_state': 42}

# %%
# Light GBM

lgbr_param_grid = {
    'boosting_type' : ['gbdt', 'dart', 'rf', 'goss']
    , 'gamma' : loguniform(1e-3, 1e-1)
    , 'max_depth' : stats.randint(-1, 5)
    , 'learning_rate' : loguniform(1e-3, 1e0)
    , 'random_state' : [42]
}

lgbr_grid = RandomizedSearchCV(lightgbm.LGBMRegressor(), lgbr_param_grid, refit=True, verbose=2)

lgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lgbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END boosting_type=goss, gamma=0.011466240935797812, learning_rate=0.007896941231469617, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.011466240935797812, learning_rate=0.007896941231469617, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.011466240935797812, learning_rate=0.007896941231469617, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.011466240935797812, learning_rate=0.007896941231469617, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.011466240935797812, learning_rate=0.007896941231469617, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.033173639397717856, learning_rate=0.45702046798546164, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.033173639397717856, learning_rate=0.45702046798546164, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.033173639397717856, learning_rate=0.45702046798546164, max_depth=4, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.033173639397717856, learning_rate=0.45702046798546164, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.033173639397717856, learning_rate=0.45702046798546164, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.07588565637225886, learning_rate=0.2483376247266664, max_depth=4, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.07588565637225886, learning_rate=0.2483376247266664, max_depth=4, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.07588565637225886, learning_rate=0.2483376247266664, max_depth=4, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.07588565637225886, learning_rate=0.2483376247266664, max_depth=4, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.07588565637225886, learning_rate=0.2483376247266664, max_depth=4, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.007090596882150727, learning_rate=0.00886302955372061, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.007090596882150727, learning_rate=0.00886302955372061, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.007090596882150727, learning_rate=0.00886302955372061, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.007090596882150727, learning_rate=0.00886302955372061, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.007090596882150727, learning_rate=0.00886302955372061, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=rf, gamma=0.001858838744553763, learning_rate=0.0010135842884387294, max_depth=0, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.001858838744553763, learning_rate=0.0010135842884387294, max_depth=0, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.001858838744553763, learning_rate=0.0010135842884387294, max_depth=0, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.001858838744553763, learning_rate=0.0010135842884387294, max_depth=0, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.001858838744553763, learning_rate=0.0010135842884387294, max_depth=0, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.028057469880912247, learning_rate=0.0018857472922788844, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.028057469880912247, learning_rate=0.0018857472922788844, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.028057469880912247, learning_rate=0.0018857472922788844, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.028057469880912247, learning_rate=0.0018857472922788844, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.028057469880912247, learning_rate=0.0018857472922788844, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.006080983794547789, learning_rate=0.13167809079461595, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.006080983794547789, learning_rate=0.13167809079461595, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.006080983794547789, learning_rate=0.13167809079461595, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.006080983794547789, learning_rate=0.13167809079461595, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.006080983794547789, learning_rate=0.13167809079461595, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.09108205850655376, learning_rate=0.14159943262696575, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.09108205850655376, learning_rate=0.14159943262696575, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.09108205850655376, learning_rate=0.14159943262696575, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.09108205850655376, learning_rate=0.14159943262696575, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.09108205850655376, learning_rate=0.14159943262696575, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01943292120969448, learning_rate=0.009849452976951875, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01943292120969448, learning_rate=0.009849452976951875, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01943292120969448, learning_rate=0.009849452976951875, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01943292120969448, learning_rate=0.009849452976951875, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01943292120969448, learning_rate=0.009849452976951875, max_depth=4, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.008421794353389531, learning_rate=0.013162348536746948, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.008421794353389531, learning_rate=0.013162348536746948, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.008421794353389531, learning_rate=0.013162348536746948, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.008421794353389531, learning_rate=0.013162348536746948, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.008421794353389531, learning_rate=0.013162348536746948, max_depth=3, random_state=42; total time=   0.1s
# The best parameters are  {'boosting_type': 'gbdt', 'gamma': 0.033173639397717856, 'learning_rate': 0.45702046798546164, 'max_depth': 4, 'random_state': 42}

# %%
# SGD regressor

sgdr_param_grid = {
    'learning_rate' : ['constant', 'optimal', 'invscaling', 'adaptive']
    , 'alpha' : loguniform(1e-5, 1e-2)
    , 'random_state' : [42]
}

sgdr_grid = RandomizedSearchCV(linear_model.SGDRegressor(), sgdr_param_grid, refit=True, verbose=2)

sgdr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', sgdr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END alpha=0.004484585452411359, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.004484585452411359, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.004484585452411359, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.004484585452411359, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.004484585452411359, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001166678101674488, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001166678101674488, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001166678101674488, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001166678101674488, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001166678101674488, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=3.8385832683583976e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=3.8385832683583976e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=3.8385832683583976e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=3.8385832683583976e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=3.8385832683583976e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.008503495151816361, learning_rate=optimal, random_state=42; total time=   0.6s
# [CV] END alpha=0.008503495151816361, learning_rate=optimal, random_state=42; total time=   0.5s
# [CV] END alpha=0.008503495151816361, learning_rate=optimal, random_state=42; total time=   0.6s
# [CV] END alpha=0.008503495151816361, learning_rate=optimal, random_state=42; total time=   0.3s
# [CV] END alpha=0.008503495151816361, learning_rate=optimal, random_state=42; total time=   0.6s
# [CV] END alpha=7.84651408913293e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=7.84651408913293e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=7.84651408913293e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=7.84651408913293e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=7.84651408913293e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.00020493045051156214, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.00020493045051156214, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.00020493045051156214, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.00020493045051156214, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.00020493045051156214, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.004030311181732479, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.004030311181732479, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.004030311181732479, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.004030311181732479, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.004030311181732479, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.00041025874581289374, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.00041025874581289374, learning_rate=optimal, random_state=42; total time=   0.0s
# [CV] END alpha=0.00041025874581289374, learning_rate=optimal, random_state=42; total time=   0.2s
# [CV] END alpha=0.00041025874581289374, learning_rate=optimal, random_state=42; total time=   0.2s
# [CV] END alpha=0.00041025874581289374, learning_rate=optimal, random_state=42; total time=   0.0s
# [CV] END alpha=0.001575165444028818, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001575165444028818, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001575165444028818, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001575165444028818, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001575165444028818, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.003974513629048665, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.003974513629048665, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.003974513629048665, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.003974513629048665, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.003974513629048665, learning_rate=adaptive, random_state=42; total time=   0.1s
# The best parameters are  {'alpha': 0.003974513629048665, 'learning_rate': 'adaptive', 'random_state': 42}

# %%
linr_param_grid = {
    'copy_X' : [True]
    , 'n_jobs' : [-1]
}

linr_grid = RandomizedSearchCV(linear_model.LinearRegression(), linr_param_grid, refit=True, verbose=2)

linr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', linr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# The best parameters are  {'n_jobs': -1, 'copy_X': True}
