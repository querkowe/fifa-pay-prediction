# %% [markdown]
# # Prediction By Machine Learning
#
# ### Install

# %%
# !pip install tqdm
# !pip install lightgbm
# !pip install xgboost
# !pip install vecstack
# !pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightgbm) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.7.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vecstack in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (3.1.0)

# %% [markdown]
# ### Import

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, RobustScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error

from skopt import BayesSearchCV
from skopt.space import Categorical, Integer, LogN, Real
import scipy.stats as stats

from sklearn import linear_model, svm, ensemble
from xgboost import XGBRegressor
import lightgbm

from vecstack import StackingTransformer

from collections import Counter

from tqdm import tqdm

# %% [markdown]
# ### Prepare the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/03_work_code/Querkowe
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/220919/fifa_pay_prediction/03_work_code/Querkowe

# %%
train_data = pd.read_csv('../../00_original_data/FIFA_train.csv')

# %%
train_data.head()
# Out:
#    id          name  age      continent contract_until position prefer_foot  \
# 0   0      L. Messi   31  south america           2021       ST        left
# 1   3        De Gea   27         europe           2020       GK       right
# 2   7     L. Suárez   31  south america           2021       ST       right
# 3   8  Sergio Ramos   32         europe           2020       DF       right
# 4   9      J. Oblak   25         europe           2021       GK       right
#
#    reputation  stat_overall  stat_potential  stat_skill_moves        value
# 0         5.0            94              94               4.0  110500000.0
# 1         4.0            91              93               1.0   72000000.0
# 2         5.0            91              91               3.0   80000000.0
# 3         4.0            91              91               3.0   51000000.0
# 4         3.0            90              93               1.0   68000000.0

# %%
train_data.shape
# Out:
# (8932, 12)

# %%
#contract_until 변수 int 형으로 변환
# 계약 연도만 추출
def func(string:object) -> int:
    """계약 연도만 추출하여 int로 반환"""
    string = string[-4:]
    return int(string)


train_data['contract_until'] = train_data['contract_until'].apply(func)

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data[train_data.keys().drop(['id', 'name', 'value'])], train_data['value'])

# %%
x_train.head()
# Out:
#       age continent  contract_until position prefer_foot  reputation  \
# 8269   21   oceania            2019       MF       right         1.0
# 599    27    europe            2019       MF       right         2.0
# 319    33    europe            2019       DF       right         3.0
# 3284   22    europe            2020       DF       right         1.0
# 6578   20    europe            2020       MF        left         1.0
#
#       stat_overall  stat_potential  stat_skill_moves
# 8269            57              68               2.0
# 599             77              77               4.0
# 319             80              80               2.0
# 3284            69              77               2.0
# 6578            63              77               3.0

# %%
x_test.shape
# Out:
# (2233, 9)

# %% [markdown]
# #### Pipeline Preprocess

# %%
numeric_features = ['age', 'reputation', 'stat_overall', 'stat_potential', 'stat_skill_moves']
numeric_transformer = StandardScaler() # RobustScaler

categorical_features = ['continent', 'position', 'prefer_foot']
categorical_transformer = OneHotEncoder(categories='auto', handle_unknown='ignore') 

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
preprocessor_pipe = Pipeline(steps=[('preprocessor', preprocessor)])

preprocessor_pipe.fit(x_train)

x_train_transformed = preprocessor_pipe.transform(x_train)

# %% [markdown]
# ### Grid Search

# %%
svr_param_grid = {'C' : [0.1, 1, 10, 100, 1000], 
             'gamma' : [1, 0.1, 0.01, 0.001, 0.0001],
             'kernel' : ['rbf']}

svr_grid = GridSearchCV(svm.SVR(), svr_param_grid, refit=True, verbose=2)

svr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', svr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   3.5s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   3.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.7s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.7s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   2.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.7s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   4.5s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.1s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.4s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   2.5s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   3.3s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.9s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   3.1s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.8s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.6s
# The best parameters are  {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
lsvr_param_grid = {'C' : [0.1, 1, 10, 100, 1000]
                   , 'random_state' : [42]}

lsvr_grid = GridSearchCV(svm.LinearSVR(), lsvr_param_grid, refit=True, verbose=2)

lsvr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lsvr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END .............................C=0.1, random_state=42; total time=   0.0s
# [CV] END .............................C=0.1, random_state=42; total time=   0.0s
# [CV] END .............................C=0.1, random_state=42; total time=   0.0s
# [CV] END .............................C=0.1, random_state=42; total time=   0.0s
# [CV] END .............................C=0.1, random_state=42; total time=   0.0s
# [CV] END ...............................C=1, random_state=42; total time=   0.0s
# [CV] END ...............................C=1, random_state=42; total time=   0.0s
# [CV] END ...............................C=1, random_state=42; total time=   0.0s
# [CV] END ...............................C=1, random_state=42; total time=   0.0s
# [CV] END ...............................C=1, random_state=42; total time=   0.0s
# [CV] END ..............................C=10, random_state=42; total time=   0.0s
# [CV] END ..............................C=10, random_state=42; total time=   0.0s
# [CV] END ..............................C=10, random_state=42; total time=   0.0s
# [CV] END ..............................C=10, random_state=42; total time=   0.0s
# [CV] END ..............................C=10, random_state=42; total time=   0.0s
# [CV] END .............................C=100, random_state=42; total time=   0.0s
# [CV] END .............................C=100, random_state=42; total time=   0.0s
# [CV] END .............................C=100, random_state=42; total time=   0.0s
# [CV] END .............................C=100, random_state=42; total time=   0.0s
# [CV] END .............................C=100, random_state=42; total time=   0.0s
# [CV] END ............................C=1000, random_state=42; total time=   0.0s
# [CV] END ............................C=1000, random_state=42; total time=   0.0s
# [CV] END ............................C=1000, random_state=42; total time=   0.0s
# [CV] END ............................C=1000, random_state=42; total time=   0.0s
# [CV] END ............................C=1000, random_state=42; total time=   0.0s
# The best parameters are  {'C': 1000, 'random_state': 42}

# %%
xtr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [-1, 3, 5]
    , 'random_state' : [42]
}

xtr_grid = GridSearchCV(ensemble.ExtraTreesRegressor(), xtr_param_grid, refit=True, verbose=2)

xtr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xtr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.5s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.4s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.4s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.8s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.7s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.7s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.7s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.7s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.7s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.1s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.3s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.1s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.2s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.2s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.0s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.2s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.1s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.1s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.3s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.3s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.3s
# The best parameters are  {'max_depth': 5, 'n_estimators': 1000, 'n_jobs': -1, 'random_state': 42}

# %%
rfr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [-1, 3, 5]
    , 'random_state' : [42]
}

rfr_grid = GridSearchCV(ensemble.RandomForestRegressor(), rfr_param_grid, refit=True, verbose=2)

rfr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', rfr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.1s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.3s
# [CV] END max_depth=-1, n_estimators=500, n_jobs=-1, random_state=42; total time=   1.2s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.5s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=-1, n_estimators=1000, n_jobs=-1, random_state=42; total time=   1.4s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   1.6s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=3, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.5s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=3, n_estimators=200, n_jobs=-1, random_state=42; total time=   0.9s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=3, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.1s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.8s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.9s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.8s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.9s
# [CV] END max_depth=3, n_estimators=1000, n_jobs=-1, random_state=42; total time=   3.8s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=100, n_jobs=-1, random_state=42; total time=   0.6s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=5, n_estimators=200, n_jobs=-1, random_state=42; total time=   1.1s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=5, n_estimators=500, n_jobs=-1, random_state=42; total time=   2.6s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   5.0s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   5.1s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   5.0s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   4.9s
# [CV] END max_depth=5, n_estimators=1000, n_jobs=-1, random_state=42; total time=   5.0s
# The best parameters are  {'max_depth': 5, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 42}

# %%
gbr_param_grid = {
    'n_estimators' : [10, 100, 1000]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1]
    , 'random_state' : [42]
}

gbr_grid = GridSearchCV(ensemble.GradientBoostingRegressor(), gbr_param_grid, refit=True, verbose=2)

gbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', gbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   4.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   4.3s
# [CV] END learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   6.4s
# The best parameters are  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'random_state': 42}

# %%
xgbr_param_grid = {
    'n_estimators' : [10, 100, 1000]
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1]
    , 'random_state' : [42]
}

xgbr_grid = GridSearchCV(XGBRegressor(), xgbr_param_grid, refit=True, verbose=2)

xgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xgbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [09:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:22:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:22:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:22:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:22:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:22:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:22:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:22:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:22:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:22:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:22:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:22:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:22:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:22:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:22:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:22:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:22:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   3.0s
# [09:23:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:23:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:23:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:23:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:23:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:23:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:23:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.6s
# [09:23:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:23:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:23:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.4s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:23:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:23:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:24:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:24:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:24:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.8s
# [09:24:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:24:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:24:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:24:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:24:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100, random_state=42; total time=   0.4s
# [09:24:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   3.0s
# [09:24:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:24:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:24:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:24:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:24:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:24:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:24:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:24:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:25:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.001, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:25:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:25:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:25:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:25:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# ...
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:27:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.4s
# [09:27:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.6s
# [09:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:27:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.5s
# [09:27:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.01, max_depth=5, n_estimators=1000, random_state=42; total time=   4.4s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=100, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=-1, n_estimators=1000, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=10, random_state=42; total time=   0.0s
# [09:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=100, random_state=42; total time=   0.3s
# [09:27:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:28:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   3.0s
# [09:28:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:28:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=3, n_estimators=1000, random_state=42; total time=   2.9s
# [09:28:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:28:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=10, random_state=42; total time=   0.1s
# [09:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:28:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=100, random_state=42; total time=   0.5s
# [09:28:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.6s
# [09:28:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:28:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:28:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.7s
# [09:28:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV] END gamma=0.001, learning_rate=0.1, max_depth=5, n_estimators=1000, random_state=42; total time=   4.6s
# [09:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# The best parameters are  {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'random_state': 42}

# %%
# Light GBM

lgbr_param_grid = {
    'boosting_type' : ['gbdt', 'dart', 'rf', 'goss']
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1, 1]
    , 'random_state' : [42]
}

lgbr_grid = GridSearchCV(lightgbm.LGBMRegressor(), lgbr_param_grid, refit=True, verbose=2)

lgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lgbr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=gbdt, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.3s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.4s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=dart, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.2s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# [CV] END boosting_type=rf, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.0s
# ...
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.1, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.01, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.2s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.001, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=-1, random_state=42; total time=   0.2s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.01, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=0.1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=-1, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=3, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.1s
# [CV] END boosting_type=goss, gamma=0.001, learning_rate=1, max_depth=5, random_state=42; total time=   0.0s
# The best parameters are  {'boosting_type': 'dart', 'gamma': 0.1, 'learning_rate': 1, 'max_depth': -1, 'random_state': 42}

# %%
# SGD regressor

sgdr_param_grid = {
    'learning_rate' : ['constant', 'optimal', 'invscaling', 'adaptive']
    , 'alpha' : [0.00001, 0.0001, 0.001 ,0.01]
    , 'random_state' : [42]
}

sgdr_grid = GridSearchCV(linear_model.SGDRegressor(), sgdr_param_grid, refit=True, verbose=2)

sgdr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', sgdr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END alpha=1e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=1e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=1e-05, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.0001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.0001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=optimal, random_state=42; total time=   0.3s
# [CV] END alpha=0.001, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=optimal, random_state=42; total time=   0.3s
# [CV] END alpha=0.001, learning_rate=optimal, random_state=42; total time=   0.2s
# [CV] END alpha=0.001, learning_rate=optimal, random_state=42; total time=   0.2s
# [CV] END alpha=0.001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.001, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.01, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=constant, random_state=42; total time=   0.0s
# [CV] END .alpha=0.01, learning_rate=optimal, random_state=42; total time=   0.6s
# [CV] END .alpha=0.01, learning_rate=optimal, random_state=42; total time=   0.2s
# [CV] END .alpha=0.01, learning_rate=optimal, random_state=42; total time=   0.6s
# [CV] END .alpha=0.01, learning_rate=optimal, random_state=42; total time=   0.0s
# [CV] END .alpha=0.01, learning_rate=optimal, random_state=42; total time=   0.1s
# [CV] END alpha=0.01, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=invscaling, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=adaptive, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.01, learning_rate=adaptive, random_state=42; total time=   0.1s
# [CV] END alpha=0.01, learning_rate=adaptive, random_state=42; total time=   0.0s
# [CV] END alpha=0.01, learning_rate=adaptive, random_state=42; total time=   0.1s
# The best parameters are  {'alpha': 0.001, 'learning_rate': 'adaptive', 'random_state': 42}

# %%
linr_param_grid = {
    'copy_X' : [True]
    , 'n_jobs' : [-1]
}

linr_grid = GridSearchCV(linear_model.LinearRegression(), linr_param_grid, refit=True, verbose=2)

linr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', linr_grid.best_params_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.1s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# [CV] END .............................copy_X=True, n_jobs=-1; total time=   0.0s
# The best parameters are  {'copy_X': True, 'n_jobs': -1}

# %% [markdown]
# ### Random Search

# %%
svr_param_grid = {'C' : LogN(), 
             'gamma' : [1, 0.1, 0.01, 0.001, 0.0001],
             'kernel' : ['rbf']}

svr_grid = GridSearchCV(svm.SVR(), svr_param_grid, refit=True, verbose=2)

svr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', svr_grid.best_params_)

# %%
lsvr_param_grid = {'C' : [0.1, 1, 10, 100, 1000]
                   , 'random_state' : [42]}

lsvr_grid = GridSearchCV(svm.LinearSVR(), lsvr_param_grid, refit=True, verbose=2)

lsvr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lsvr_grid.best_params_)

# %%
xtr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [-1, 3, 5]
    , 'random_state' : [42]
}

xtr_grid = GridSearchCV(ensemble.ExtraTreesRegressor(), xtr_param_grid, refit=True, verbose=2)

xtr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xtr_grid.best_params_)

# %%
rfr_param_grid = {
    'n_estimators' : [100, 200, 500, 1000]
    , 'n_jobs' : [-1]
    , 'max_depth' : [-1, 3, 5]
    , 'random_state' : [42]
}

rfr_grid = GridSearchCV(ensemble.RandomForestRegressor(), rfr_param_grid, refit=True, verbose=2)

rfr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', rfr_grid.best_params_)

# %%
gbr_param_grid = {
    'n_estimators' : [10, 100, 1000]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1]
    , 'random_state' : [42]
}

gbr_grid = GridSearchCV(ensemble.GradientBoostingRegressor(), gbr_param_grid, refit=True, verbose=2)

gbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', gbr_grid.best_params_)

# %%
xgbr_param_grid = {
    'n_estimators' : [10, 100, 1000]
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1]
    , 'random_state' : [42]
}

xgbr_grid = GridSearchCV(XGBRegressor(), xgbr_param_grid, refit=True, verbose=2)

xgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', xgbr_grid.best_params_)

# %%
# Light GBM

lgbr_param_grid = {
    'boosting_type' : ['gbdt', 'dart', 'rf', 'goss']
    , 'gamma' : [0.1, 0.01, 0.001]
    , 'max_depth' : [-1, 3, 5]
    , 'learning_rate' : [0.001, 0.01, 0.1, 1]
    , 'random_state' : [42]
}

lgbr_grid = GridSearchCV(lightgbm.LGBMRegressor(), lgbr_param_grid, refit=True, verbose=2)

lgbr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', lgbr_grid.best_params_)

# %%
# SGD regressor

sgdr_param_grid = {
    'copy_X' : [True]
    , 'learning_rate' : ['constant', 'optimal', 'invscaling', 'adaptive']
    , 'alpha' : [0.00001, 0.0001, 0.001 ,0.01]
    , 'random_state' : [42]
}

sgdr_grid = GridSearchCV(linear_model.LinearRegression(), sgdr_param_grid, refit=True, verbose=2)

sgdr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', sgdr_grid.best_params_)

# %%
linr_param_grid = {
    'copy_X' : [True]
    , 'n_jobs' : [-1]
}

linr_grid = GridSearchCV(linear_model.LinearRegression(), linr_param_grid, refit=True, verbose=2)

linr_grid.fit(x_train_transformed, y_train)
print('The best parameters are ', linr_grid.best_params_)
